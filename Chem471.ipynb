# %%
# Your dataset should contain at least 500 rows of data; preferably over 1000, and at least five columns (four possible features and your target variable).  Recall, you can engineer features using RDKit.  If your dataset has less data than that available, discuss your situation with Dr. McDonald.  

#2. You should perform EDA to understand your dataset and do appropriate data cleaning.  

#3.  You should do a test-train split, feature engineering, modeling fitting and model testing.   It may be appropriate to try different types of models and compare them, depending on what you are trying to predict.  

#4.  You should analyze appropriate statistical metrics for your model.  

#During our class meeting in Week 10, your group will give a presentation of your project.  Your presentation should be no more than 10 minutes, including time for questions.  I recommend planning your presentation for 7-8 minutes to leave time for questions.  

#Presentation Guidelines:

#1. You should discuss the provenance of your data, i.e. where you got it, who collected it, and how it was collected.

#2. You should discuss the motivation for your model.  Why is this a useful thing to be able to predict?

#3. You should discuss the strengths and limitations of your dataset based on your EDA.  This section should include at least three visualizations to support your analysis.  

#4.  You should discuss what type of model you trained and why you chose that for your dataset.  This might include discussing multiple different type of models that you tried and why you chose the one you did.

#5.  You should discuss your model's performance and what metrics you used to judge the performance.
